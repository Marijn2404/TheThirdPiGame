# %% [markdown]
# Read Excel data into Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

df = pd.read_excel("BakeryData_Vilnius.xlsx")
stores = ["main street A","main street B","station A","station B"]
df["weekday"] = df['date'].dt.strftime('%A')
df["date"] = pd.to_datetime(df["date"]).dt.date
df
# Out:
#             date    weekday  main street A  main street B  station A  \
# 0     2016-05-11  Wednesday           2.23            NaN        NaN
# 1     2016-05-12   Thursday          18.10            NaN        NaN
# 2     2016-05-13     Friday          15.85            NaN        NaN
# 3     2016-05-14   Saturday          14.22            NaN        NaN
# 4     2016-05-15     Sunday           2.58            NaN        NaN
# ...          ...        ...            ...            ...        ...
# 2572  2023-05-27   Saturday         168.05          32.34      76.97
# 2573  2023-05-28     Sunday          44.62          32.85      80.21
# 2574  2023-05-29     Monday          64.11         116.84     149.75
# 2575  2023-05-30    Tuesday         103.63         134.48     194.03
# 2576  2023-05-31  Wednesday          39.64         125.87     165.43
#
#       station B
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# ...

# %% [markdown]
# Summary statistics for the dataset

# %%
df.describe()
# Out:
#        main street A  main street B    station A   station B
# count    2577.000000     122.000000  1746.000000  330.000000
# mean       66.527485      99.367623   114.412428  118.437606
# std        42.255709      43.547492    53.255022   45.077501
# min         1.020000      18.700000     2.530000   42.510000
# 25%        41.420000      40.442500    73.335000   90.660000
# 50%        57.870000     118.115000   121.910000  108.890000
# 75%        93.380000     131.645000   155.287500  129.307500
# max       191.880000     163.400000   275.720000  300.980000

# %%
for store in stores:
    fig = px.histogram(df, x=store, color="weekday", title="Histogram for {0}".format(store))
    fig.show()

# %%
for store in stores:
    fig = px.box(df, x=store, color="weekday", title=store)
    fig.show()

# %%
for store in stores:
    fig = px.line(df, x="date", y=store, color="weekday", title=store)
    fig.show()
