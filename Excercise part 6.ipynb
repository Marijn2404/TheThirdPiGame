# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import statsmodels.api as sm
import scipy.stats as sts
from datetime import datetime

np.random.seed(0)

df = pd.read_excel("BakeryData_Vilnius.xlsx")
stores = ["main street A","main street B","station A","station B"]
daysOfTheWeek = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df["weekday_text"] = df['date'].dt.strftime('%A')
df["date"] = pd.to_datetime(df["date"])
df
# Out:
#            date  weekday  main street A  main street B  station A  station B  \
# 0    2016-05-11        3           2.23            NaN        NaN        NaN
# 1    2016-05-12        4          18.10            NaN        NaN        NaN
# 2    2016-05-13        5          15.85            NaN        NaN        NaN
# 3    2016-05-14        6          14.22            NaN        NaN        NaN
# 4    2016-05-15        7           2.58            NaN        NaN        NaN
# ...         ...      ...            ...            ...        ...        ...
# 2572 2023-05-27        6         168.05          32.34      76.97     114.30
# 2573 2023-05-28        7          44.62          32.85      80.21      91.25
# 2574 2023-05-29        1          64.11         116.84     149.75      92.56
# 2575 2023-05-30        2         103.63         134.48     194.03      75.63
# 2576 2023-05-31        3          39.64         125.87     165.43      74.41
#
#      weekday_text
# 0       Wednesday
# 1        Thursday
# 2          Friday
# 3        Saturday
# 4          Sunday
# ...           ...
# 2572     Saturday
# 2573       Sunday
# 2574       Monday
# 2575      Tuesday
# 2576    Wednesday
#
# [2577 rows x 7 columns]

# %%
begin = datetime(day = 31,month = 12,year = 2016)
pre_covid = datetime(day = 1,month = 3,year = 2021)
after_covid = datetime(day = 1,month = 3,year = 2022)
df = df[((df["date"] < pre_covid) | (df["date"] > after_covid)) & (df["date"] > begin)]

def removeOutliers(df):
    mean = df.mean()
    sd = df.std()
    return df[(df > (mean - 3*sd)) & (df < (mean + 3*sd))]

#print(removeOutliers(df[df["weekday_text"] == "Monday"]["station A"]).mean())
#print(removeOutliers(df[df["weekday_text"] == "Monday"]["station A"]).std())

# %%
class Store():
    def __init__(self, name, p, pl, c, cs, dist):
        self.name = name
        self.p = p
        self.pl = pl
        self.c = c
        self.cs = cs
        self.overageCost = self.p - self.c
        self.underageCost = self.c + self.cs - self.pl
        self.serviceLevel = self.overageCost / ( self.overageCost + self.underageCost)
        self.dist = dist
    def fit(self, feature):
        if self.dist == sts.norm:
            return np.mean(feature), np.std(feature, ddof=1)
        if self.dist == sts.lognorm:
            return np.std(np.log(feature),ddof=1),0,np.exp(np.mean(np.log(feature)))
        else:
            raise Exception("MLE not found for given dist")
    def feature(self, day):
        feature = df[df["weekday_text"] == day][self.name]
        feature = feature[~np.isnan(feature)]
        return removeOutliers(feature)
    def bootstrap(self, day, m, alpha):
        feature = self.feature(day)
        params = self.fit(feature)
        vQ_hat = np.zeros(m)
        n = len(feature)
        for i in range(m):
            generatedData = self.dist.rvs(*params, size=n)
            btParams = self.fit(generatedData)
            vQ_hat[i] = self.dist.ppf(self.serviceLevel, *btParams)
        return np.quantile(vQ_hat, [alpha/2, 1-alpha/2])
    def nonParametricOptimalInterval(self, day, alpha):
        feature = self.feature(day)
        criticalAmount = feature.quantile(self.serviceLevel)

        # Find interval
        z = 1 / sts.norm.ppf(1-alpha/2)
        feature = np.sort(feature)
        n = len(feature)
        deviation = (z * np.sqrt(n*self.serviceLevel * (1-self.serviceLevel)))
        upperBound = int(n*self.serviceLevel + deviation)
        lowerBound = int(n*self.serviceLevel - deviation)
        if upperBound > n:
            upperBound = n
        if lowerBound < 1:
            lowerBound = 1
        minimumAmount, maximumAmount  = feature[lowerBound - 1], feature[upperBound - 1]
        return {'store':self.name,'day':day,'service-level': self.serviceLevel,'method' : "nonParametric",'optimalQuantity': criticalAmount, 'lower bound': minimumAmount, 'upper bound': maximumAmount}
    def parametricOptimalInterval(self, day, alpha, m=100):
        feature = self.feature(day)
        params = self.fit(feature)
        optimalQuantity = self.dist.ppf(self.serviceLevel, *params)
        minimumAmount, maximumAmount = self.bootstrap(day,m,alpha)
        
        return {'store':self.name,'day':day,'service-level': self.serviceLevel,'method' : "Parametric",'optimalQuantity': optimalQuantity, 'lower bound': minimumAmount, 'upper bound': maximumAmount}

# Init the stores class with the stores we will be using
mainstreetA = Store("main street A", 4.64, 0.15, 3.85, 0.11,  sts.lognorm)
stationA = Store("station A", 4.64, 0.15, 4.16, 0.08, sts.norm)
#mainstreetB = Store("main street A", 4.64, 0.15, 3.42, 0.08)
#stationB = Store("station B", 4.64, 0.15, 3.32, 0.09)
Stores = [mainstreetA, stationA]

# m = 10000 takes about 70 second to run on our hardware
m = 10000
output = []
for store in Stores:
    for day in daysOfTheWeek:
        output.append(store.nonParametricOptimalInterval(day,0.05))
        output.append(store.parametricOptimalInterval(day,0.05,m))

outputdf = pd.DataFrame(output)
outputdf["length"] = np.abs(outputdf["lower bound"]-outputdf["upper bound"])
outputdf
# Out:
#             store        day  service-level         method  optimalQuantity  \
# 0   main street A     Monday       0.171739  nonParametric        40.953217
# 1   main street A     Monday       0.171739     Parametric        40.305496
# 2   main street A    Tuesday       0.171739  nonParametric        40.690043
# 3   main street A    Tuesday       0.171739     Parametric        40.802241
# 4   main street A  Wednesday       0.171739  nonParametric        41.398304
# 5   main street A  Wednesday       0.171739     Parametric        40.796702
# 6   main street A   Thursday       0.171739  nonParametric        42.580000
# 7   main street A   Thursday       0.171739     Parametric        41.383261
# 8   main street A     Friday       0.171739  nonParametric        93.915761
# 9   main street A     Friday       0.171739     Parametric        93.983035
# 10  main street A   Saturday       0.171739  nonParametric       139.527957
# 11  main street A   Saturday       0.171739     Parametric       139.111319
# 12  main street A     Sunday       0.171739  nonParametric        42.774348
# 13  main street A     Sunday       0.171739     Parametric        40.750066
# 14      station A     Monday       0.105033  nonParametric       120.119234
# 15      station A     Monday       0.105033     Parametric       117.900599
# 16      station A    Tuesday       0.105033  nonParametric       116.277724
# 17      station A    Tuesday       0.105033     Parametric       114.604614
# 18      station A  Wednesday       0.105033  nonParametric       114.417659
# 19      station A  Wednesday       0.105033     Parametric       113.927890
# 20      station A   Thursday       0.105033  nonParametric       110.639387
# 21      station A   Thursday       0.105033     Parametric       113.046884
# 22      station A     Friday       0.105033  nonParametric       117.542123
# 23      station A     Friday       0.105033     Parametric       116.853578
# 24      station A   Saturday       0.105033  nonParametric        64.965252
# 25      station A   Saturday       0.105033     Parametric        64.634912
# 26      station A     Sunday       0.105033  nonParametric        65.029387
# 27      station A     Sunday       0.105033     Parametric        65.021266
#
#     lower bound  upper bound     length
# 0     40.540000    41.300000   0.760000
# 1     38.631651    42.048634   3.416983
# 2     39.960000    40.820000   0.860000
# 3     39.138604    42.571037   3.432433
# 4     40.280000    41.860000   1.580000
# 5     39.126059    42.606189   3.480130
# 6     42.010000    42.900000   0.890000
# 7     39.690632    43.211728   3.521096
# 8     93.690000    94.040000   0.350000
# 9     93.310991    94.657631   1.346640
# 10   138.700000   139.850000   1.150000
# 11   137.375032   140.893943   3.518911
# 12    41.850000    42.830000   0.980000
# 13    39.034773    42.601806   3.567033
# 14   118.930000   120.280000   1.350000
# 15   112.889091   122.963241  10.074150
# 16   114.650000   116.620000   1.970000
# 17   109.414254   119.929791  10.515537
# 18   112.890000   114.430000   1.540000
# 19   108.315761   119.659793  11.344033
# 20   109.600000   110.780000   1.180000
# 21   107.401289   118.767275  11.365986
# 22   114.600000   118.270000   3.670000
# 23   111.457464   122.385100  10.927636
# 24    63.990000    65.110000   1.120000
# 25    63.089960    66.202841   3.112881
# 26    63.520000    65.170000   1.650000
# 27    63.526820    66.534425   3.007605
